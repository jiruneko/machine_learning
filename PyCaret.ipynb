# %% [markdown]
# <a href="https://colab.research.google.com/github/jiruneko/3Dpeg/blob/master/PyCaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyCaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pycaret.datasets import get_data
boston = get_data("boston")
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
from pycaret.regression import *
prepro = setup(boston, target = "medv")
# Out:
# <style type="text/css">
# #T_2d8fe_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2d8fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d8fe_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2d8fe_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d8fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d8fe_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2d8fe_row0_col1" class="data row0 col1" >7686</td>
#     </tr>
#     <tr>
#       <th id="T_2d8fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d8fe_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2d8fe_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_2d8fe_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_f6a96 th {
#   text-align: left;
# }
# ...

# %%
model = create_model('et')
# Out:
# <style type="text/css">
# #T_29a97_row10_col0, #T_29a97_row10_col1, #T_29a97_row10_col2, #T_29a97_row10_col3, #T_29a97_row10_col4, #T_29a97_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_29a97" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29a97_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_29a97_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_29a97_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_29a97_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_29a97_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_29a97_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(model)
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=7686)

# %%
tuned_model = tune_model(model)
# Out:
# <style type="text/css">
# #T_8f63f_row10_col0, #T_8f63f_row10_col1, #T_8f63f_row10_col2, #T_8f63f_row10_col3, #T_8f63f_row10_col4, #T_8f63f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8f63f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f63f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8f63f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8f63f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8f63f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8f63f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8f63f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
predict_model(tuned_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7f55" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7f55_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a7f55_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a7f55_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a7f55_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a7f55_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a7f55_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a7f55_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7f55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7f55_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_a7f55_row0_col1" class="data row0 col1" >2.1304</td>
# ...

# %%
from pycaret.regression import *
prepro = setup(boston, target = "medv", train_size=0.5)
# Out:
# <style type="text/css">
# #T_e8a39_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e8a39" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8a39_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e8a39_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8a39_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8a39_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e8a39_row0_col1" class="data row0 col1" >880</td>
#     </tr>
#     <tr>
#       <th id="T_e8a39_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8a39_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e8a39_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_e8a39_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_3b4c7 th {
#   text-align: left;
# }
# ...

# %%
lightgbm = create_model("lightgbm")
# Out:
# <style type="text/css">
# #T_08f58_row10_col0, #T_08f58_row10_col1, #T_08f58_row10_col2, #T_08f58_row10_col3, #T_08f58_row10_col4, #T_08f58_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_08f58" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08f58_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_08f58_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_08f58_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_08f58_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_08f58_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_08f58_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
predict_model = predict_model(lightgbm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_75074" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75074_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_75074_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_75074_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_75074_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_75074_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_75074_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_75074_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75074_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75074_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_75074_row0_col1" class="data row0 col1" >2.7371</td>
# ...
